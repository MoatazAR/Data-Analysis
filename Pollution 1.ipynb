# %%
#AQI= Air Quality Index, range = 0-500|AQI<50 -> good air quality|AQI>300 -> hazardous air quality|
import pandas as pd
pollution_dataset=pd.read_csv('pollution_us_2000_2016.csv')
#note: p_dataset=pd.read_excel(filename.xlsx) in order to read .xlsx files

#display first few rows of a dataset using head(no. of rows)
print(pollution_dataset.head(5))
#note: print(pollution_dataset.tail(5)) to display last few rows
# Out:
#    Unnamed: 0  State Code  County Code  Site Num  \
# 0           0           4           13      3002
# 1           1           4           13      3002
# 2           2           4           13      3002
# 3           3           4           13      3002
# 4           4           4           13      3002
#
#                                    Address    State    County     City  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#    Date Local          NO2 Units  ...          SO2 Units  SO2 Mean  \
# 0  2000-01-01  Parts per billion  ...  Parts per billion  3.000000
# 1  2000-01-01  Parts per billion  ...  Parts per billion  3.000000
# ...

# %%
#display column headers
print(pollution_dataset.columns)

#read specific column (similar to 2d array)
#print(pollution_dataset['Date Local'])

#read specific columns & limit output to first 5 rows
#print(pollution_dataset[['Date Local','NO2 Units']][0:5])

#read specific row
#print(pollution_dataset.iloc[2])

#read specific location (R,C)
#print(pollution_dataset.iloc[2,1])

#filter out using loc
print(pollution_dataset.loc[pollution_dataset['City']=='Phoenix'].loc[pollution_dataset['Date Local']=='2000-01-01'])
# Out:
# Index(['Unnamed: 0', 'State Code', 'County Code', 'Site Num', 'Address',
#        'State', 'County', 'City', 'Date Local', 'NO2 Units', 'NO2 Mean',
#        'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI', 'O3 Units',
#        'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI', 'SO2 Units',
#        'SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI',
#        'CO Units', 'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI'],
#       dtype='object')
#    Unnamed: 0  State Code  County Code  Site Num  \
# 0           0           4           13      3002
# 1           1           4           13      3002
# 2           2           4           13      3002
# 3           3           4           13      3002
#
#                                    Address    State    County     City  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# ...

# %%
#get general data about dataset
#pollution_dataset.describe()

#sort data by column values, add ascending=FALSE or TRUE to make it ascending/descending
pollution_dataset.sort_values('City')
# Out:
#          Unnamed: 0  State Code  County Code  Site Num             Address  \
# 1552656       88244          35            1        23  4700A SAN MATEO NE
# 1683502       87501          35            1        23  4700A SAN MATEO NE
# 1683501       87500          35            1        23  4700A SAN MATEO NE
# 1683500       87499          35            1        23  4700A SAN MATEO NE
# 1683499       87498          35            1        23  4700A SAN MATEO NE
# ...             ...         ...          ...       ...                 ...
# 1576041      111629          42          133         8            HILL ST.
# 1576040      111628          42          133         8            HILL ST.
# 1576039      111627          42          133         8            HILL ST.
# 1576061      111649          42          133         8            HILL ST.
# 81807         81807          42          133         8            HILL ST.
#
# ...

# %%
pollution_dataset.tail(5)
# Out:
#          Unnamed: 0  State Code  County Code  Site Num  \
# 1746656       24599          56           21       100
# 1746657       24600          56           21       100
# 1746658       24601          56           21       100
# 1746659       24602          56           21       100
# 1746660       24603          56           21       100
#
#                                        Address    State   County  \
# 1746656  NCore - North Cheyenne Soccer Complex  Wyoming  Laramie
# 1746657  NCore - North Cheyenne Soccer Complex  Wyoming  Laramie
# 1746658  NCore - North Cheyenne Soccer Complex  Wyoming  Laramie
# 1746659  NCore - North Cheyenne Soccer Complex  Wyoming  Laramie
# 1746660  NCore - North Cheyenne Soccer Complex  Wyoming  Laramie
#
#                   City  Date Local          NO2 Units  ...          SO2 Units  \
# 1746656  Not in a city  2016-03-30  Parts per billion  ...  Parts per billion
# 1746657  Not in a city  2016-03-31  Parts per billion  ...  Parts per billion
# ...

# %%
#To add the concatenation of certain columns to a new column: df['newColName']=df['col1']+df['col2']+etc/df['newColName']=df.iloc[:,firstColIndex:lastColIndex+1].sum(axis=1)
#To remove a column, use drop & set dataframe to equal the statement (otherwise it won't modify it)
#pollution_dataset=pollution_dataset.drop(columns=['Unnamed: 0'])

#pollution_dataset.head(5)

#reordering columns
pollution_dataset = pollution_dataset[['State Code', 'County Code', 'Site Num', 'State', 'County', 'City', 'Address', 'Date Local', 'NO2 Units', 'NO2 Mean', 'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI', 'O3 Units', 'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI', 'SO2 Units', 'SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI', 'CO Units', 'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI']]
pollution_dataset.head(5)

#to export altered csv: dfName.to_csv('csvName.csv',index=FALSE)
# Out:
#    State Code  County Code  Site Num    State    County     City  \
# 0           4           13      3002  Arizona  Maricopa  Phoenix
# 1           4           13      3002  Arizona  Maricopa  Phoenix
# 2           4           13      3002  Arizona  Maricopa  Phoenix
# 3           4           13      3002  Arizona  Maricopa  Phoenix
# 4           4           13      3002  Arizona  Maricopa  Phoenix
#
#                                    Address  Date Local          NO2 Units  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  2000-01-01  Parts per billion
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  2000-01-01  Parts per billion
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  2000-01-01  Parts per billion
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  2000-01-01  Parts per billion
# 4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  2000-01-02  Parts per billion
#
#     NO2 Mean  ...          SO2 Units  SO2 Mean  SO2 1st Max Value  \
# ...

# %%
import re
#for filtering for multiple conditions with loc, df.loc[(df['colName1']=='cond1') & (df['colName2']=='cond2') & (df['colName3']>=number)] use | for 'or'

#to reset indeces of altered df, df=df.reset_index()

#to filter out fields that contain specific strings, df.loc[~df['desiredCol'].str.contains('DesiredStr')], ~ is equivalent to !

pollution_dataset.loc[pollution_dataset['State'].str.contains('Arizona|Nevada', regex=True)]
# Out:
#          State Code  County Code  Site Num    State    County     City  \
# 0                 4           13      3002  Arizona  Maricopa  Phoenix
# 1                 4           13      3002  Arizona  Maricopa  Phoenix
# 2                 4           13      3002  Arizona  Maricopa  Phoenix
# 3                 4           13      3002  Arizona  Maricopa  Phoenix
# 4                 4           13      3002  Arizona  Maricopa  Phoenix
# ...             ...          ...       ...      ...       ...      ...
# 1737334          32           31        16   Nevada    Washoe     Reno
# 1737335          32           31        16   Nevada    Washoe     Reno
# 1737336          32           31        16   Nevada    Washoe     Reno
# 1737337          32           31        16   Nevada    Washoe     Reno
# 1737338          32           31        16   Nevada    Washoe     Reno
#
#                                          Address  Date Local  \
# ...

# %%
#changing a value in df to different value
pollution_dataset.loc[pollution_dataset['City']=='Fénix', 'City']="Phoenix"

#to change multiple values in df, df.loc[df['conditionCol']=='requiredVal',['colChange1','colChange2','colChange3']]=['value1','value2','value3']
pollution_dataset.head(5)
# Out:
#    State Code  County Code  Site Num    State    County     City  \
# 0           4           13      3002  Arizona  Maricopa  Phoenix
# 1           4           13      3002  Arizona  Maricopa  Phoenix
# 2           4           13      3002  Arizona  Maricopa  Phoenix
# 3           4           13      3002  Arizona  Maricopa  Phoenix
# 4           4           13      3002  Arizona  Maricopa  Phoenix
#
#                                    Address  Date Local          NO2 Units  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  2000-01-01  Parts per billion
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  2000-01-01  Parts per billion
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  2000-01-01  Parts per billion
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  2000-01-01  Parts per billion
# 4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  2000-01-02  Parts per billion
#
#     NO2 Mean  ...          SO2 Units  SO2 Mean  SO2 1st Max Value  \
# ...

# %%
new_df = pollution_dataset.groupby(['City']).mean()
# Out:
# 29

# %%
new_df.iloc[29]
# Out:
# State Code           17.000000
# County Code          31.000000
# Site Num             63.000000
# NO2 Mean             31.505439
# NO2 1st Max Value    49.233216
# NO2 1st Max Hour     12.293286
# NO2 AQI              46.869258
# O3 Mean               0.012621
# O3 1st Max Value      0.020682
# O3 1st Max Hour      11.388693
# O3 AQI               17.519435
# SO2 Mean              4.638736
# SO2 1st Max Value    11.010247
# SO2 1st Max Hour     10.074205
# SO2 AQI              17.763251
# CO Mean               0.632211
# CO 1st Max Value      1.069081
# CO 1st Max Hour      10.263251
# CO AQI               10.215548
# Name: Chicago, dtype: float64

# %%
#aggregate statistics: group by to remove duplicates (finds mean of row values that share city), use sorted values to 
#new_df = pollution_dataset.groupby(['City']).mean()#.sort_values('CO Mean')
#you can use count() to get the number of rows with groupby value or sum() to add all values of data fields with groupbu value

pollution_dataset['count']=1
pollution_dataset.groupby(['City']).count()['count']
# Out:
# City
# Albuquerque       7130
# Alexandria        5876
# Altoona           7580
# Annandale         4042
# Arden-Arcade     19878
#                  ...
# Wilkes-Barre      2254
# Wilmington        3630
# Winston-Salem     1942
# Winter Park      23346
# York             15768
# Name: count, Length: 144, dtype: int64

# %%
polldf=pollution_dataset.dropna()
polldf
# Out:
#          State Code  County Code  Site Num    State    County           City  \
# 1                 4           13      3002  Arizona  Maricopa        Phoenix
# 5                 4           13      3002  Arizona  Maricopa        Phoenix
# 9                 4           13      3002  Arizona  Maricopa        Phoenix
# 13                4           13      3002  Arizona  Maricopa        Phoenix
# 17                4           13      3002  Arizona  Maricopa        Phoenix
# ...             ...          ...       ...      ...       ...            ...
# 1746642          56           21       100  Wyoming   Laramie  Not in a city
# 1746646          56           21       100  Wyoming   Laramie  Not in a city
# 1746650          56           21       100  Wyoming   Laramie  Not in a city
# 1746654          56           21       100  Wyoming   Laramie  Not in a city
# 1746658          56           21       100  Wyoming   Laramie  Not in a city
#
# ...
